# %% [markdown]
# ## 1A: English Dictionary AppThis project uses the skills learnt from week 1 to week 6. The aim of this project is to create an English Dictionary app that returns definitions of English words. When the application is started, it displays a menu as follows:
#
# Main Menu
#
# Add a new word
# Find the meaning
# Update a word
# Exit

# %%
import json

print('Welcome to the Dictionary App')
print('Please select your choice')
print('1. Add a word')
print('2. Find the meaning')
print('3. Update the word')
print('4. Exit')
f = open('words.txt','w')
coll_words = {}
json.dump(coll_words,f)
f.close()
while True:
    n = int(input('Enter the Choice:'))
    if n == 1:
        import json
        f = open('words.txt','w')
        word = input('Enter a word : ')
        meaning = input('Enter its meaning : ')
        coll_words[word] = meaning
        json.dump(coll_words,f)
        f.close()

    elif n == 2:
        import json
        f = open('words.txt','r+')
        dic = json.load(f)
        find = input('Enter the word to find: ')
        if find in coll_words:
            print('The meaning is',coll_words.get(find))
        else:
            print('Sorry the word is not found')
        json.dump(coll_words,f)
        f.close()
    elif n == 3:
        import json
        f = open('words.txt','w')
        word1 = input('Enter the word:')
        update_meaning = input('Enter the updated meaning: ')
        coll_words[word1] = update_meaning
        json.dump(coll_words,f)
        f.close()
    elif n == 4:
        print('Thank you for choosing Dictionary app')
        break
    else:
        print('Please enter the mentioned choice')
        print('1. Add a word')
        print('2. Find the meaning')
        print('3. Update the word')
        print('4. Exit')
# Out:
# Welcome to the Dictionary App
# Please select your choice
# 1. Add a word
# 2. Find the meaning
# 3. Update the word
# 4. Exit
# Welcome to the Dictionary App
# Please select your choice
# 1. Add a word
# 2. Find the meaning
# 3. Update the word
# 4. Exit
# Enter the Choice:1
# Enter a word : cat
# Enter its meaning :  it is a pet animal
# Enter the Choice:2
# Enter the word to find: add
# Sorry the word is not found
# Sorry the word is not found
# Enter the Choice:3
# Enter the word:mobile
# Enter the updated meaning:  it is an electronic object but  world is behind of this
# Enter the Choice:4
# Thank you for choosing Dictionary app
# Thank you for choosing Dictionary app

# %% [markdown]
# ## 1B. LIBRARY OF MANAGEMENT APPLICATION

# %%
#libraries
from tkinter import*
import sqlite3
import tkinter.ttk as ttk
import tkinter.messagebox as tkmessageBox
root=Tk()
root.title('CRUD')
#methods
def Database():
    global conn,cursor
    conn=sqlite3.connect('library.db')
    cursor=conn.cursor()
    cursor.execute("CREATE TABLE IF NOT EXISTS  books (book_id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,Booktitle TEXT,Authour TEXT,year INT,ISBN TEXT)")
def Create():
    if BOOKTITLE.get() == "" or AUTHOUR.get() == "" or YEAR.get() == "" or ISBN.get() == "" :
        txt_result.config(text="Please enterall the fields",fg="red")
        
    else:
        Database()
        cursor.execute("INSERT INTO books (Booktitle,Authour,year,ISBN)VALUES(?,?,?,?)",(str(BOOKTITLE.get()),str(AUTHOUR.get()),str(YEAR.get()),str(ISBN.get())))
        conn.commit()
        BOOKTITLE.SET("")
        AURHOUR.SET("")
        YEAR.SET("")
        ISBN.SET("")
        cursor.close()
        conn.close()
        txt_result.config(text="record inserted!",fg="green")
        
def Read():
    tree.delete(*tree.get_children())
    Database()
    cursor.execute("SELECT *FROM books ORDER BY Authour ASC")
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
    cursor.close()
    txt_result.config(text="succesfully fetched data!",fg="green")
    
def Add():
    tree.delete(*tree.get_children())
    Database()
    cursor.execute("SELECT *FROM books ORDER BY Authour ASC")
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
    cursor.close()
    txt_result.config(text="succesfully fetched data!",fg="blue")
        
    
    
def Exit():
    result=tkmessageBox.askquestion('Do you want to exit?(y/n)',icon='warning' )
    if result=='yes':
        root.destroy()
        exit()
#variable declaration
BOOKTITLE=StringVar()
AUTHOUR=StringVar()
YEAR=StringVar()
ISBN=StringVar()
#frame
Top=Frame(root, width =900,height=50,bd=8,relief='raise',bg="blue")
Top.pack(side=TOP)

Left=Frame(root,width=300,height=500,bd=8,relief='raise',bg="red")
Left.pack(side=LEFT)

Right=Frame(root,width=600,height=500,bd=8,relief='raise',bg="yellow")
Right.pack(side=RIGHT)

Forms=Frame(Left,width=300,height=100,bd=8,relief='raise',bg="yellow")
Forms.pack(side=TOP)

Buttons=Frame(Left,width=300,height=100,bd=8,relief='raise')
Buttons.pack(side=BOTTOM)

txt_title = Label(Top,width=900,font=('arial',24),text="....Library Management Application")
txt_title.pack()

txt_Booktitle=Label(Forms,text="Booktitle:",font=('arial',16),bd=15)
txt_Booktitle.grid(row=0,stick="e")

txt_Authour=Label(Forms,text="Authour:",font=('arial',16),bd=15)
txt_Authour.grid(row=1,stick="e")

txt_Year=Label(Forms,text="Year:",font=('arial',16),bd=15)
txt_Year.grid(row=2,stick="e")

txt_ISBN=Label(Forms,text="ISBN:",font=('arial',16),bd=15)
txt_ISBN.grid(row=3,stick="e")


txt_result=Label(Buttons)
txt_result.pack(side=TOP)

#ENTRY WIDGET
Booktitle=Entry(Forms,textvariable=BOOKTITLE,width=30)
Booktitle.grid(row=0,column=1)

Authour=Entry(Forms,textvariable=AUTHOUR,width=30)
Authour.grid(row=1,column=1)

Year=Entry(Forms,textvariable=YEAR,width=30)
Year.grid(row=2,column=1)

ISBN=Entry(Forms,textvariable=ISBN,width=30)
ISBN.grid(row=3,column=1)

btn_Display=Button(Buttons,width=10,text="Display",command=Create)
btn_Display.pack(side=LEFT)

btn_Search=Button(Buttons,width=10,text="Search",command=Read)
btn_Search.pack(side=LEFT)

btn_Add=Button(Buttons,width=10,text="Add",command=Add)
btn_Add.pack(side=LEFT)

btn_update=Button(Buttons,width=10,text="Update",state=DISABLED)
btn_update.pack(side=LEFT)



btn_delete=Button(Buttons,width=10,text="DELETE",state=DISABLED)
btn_delete.pack(side=LEFT)
btn_exit=Button(Buttons,width=10,text="Exit",command=Exit)
btn_exit.pack(side=LEFT)
#list widget
scrollbary= Scrollbar(Right, orient=VERTICAL)
scrollbarx= Scrollbar(Right, orient=HORIZONTAL)
tree=ttk.Treeview(Right,columns=("Booktitle","Authour","","Year","ISBN"))
scrollbary.config(command=tree.yview)
scrollbary.pack(side=RIGHT,fill=Y)
scrollbarx.config(command=tree.xview)
scrollbarx.pack(side=BOTTOM,fill=X)
tree.heading('Booktitle',text="Booktitle",anchor=W)
tree.heading('Authour',text="Authour",anchor=W)
tree.heading('Year',text="Year",anchor=W)
tree.heading('ISBN',text="ISBN",anchor=W)

tree.column('#0',stretch=NO,minwidth=0,width=0)
tree.column('#1',stretch=NO,minwidth=0,width=80)
tree.column('#2',stretch=NO,minwidth=0,width=120)
tree.column('#3',stretch=NO,minwidth=0,width=80)
tree.column('#4',stretch=NO,minwidth=0,width=150)

tree.pack()

if __name__=='__main__':
    root.mainloop()
